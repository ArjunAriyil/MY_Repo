# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunAriyil/Test_Repo/blob/master/Drive2Git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd '/content/drive/MyDrive/Sync/Documents/djangoweb-new'
# Out:
# /content/drive/MyDrive/Sync/Documents/djangoweb-new

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Sync/Documents/djangoweb-new'

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Sync/Documents/djangoweb-new/.git/

# %%
# !git add .

# %%
# !git config --global user.email "arjunsuresh2007@gmail.com"
# !git config --global user.name "Arjun Ariyil"

# %%
# !git commit -m "adding files"
# Out:
# [master (root-commit) 4dbccc6] adding files
#  652 files changed, 2011717 insertions(+)
#  create mode 100644 Licence.txt
#  create mode 100644 Notes.txt
#  create mode 100644 StartJupyter.bat
#  create mode 100644 Startconda.bat
#  create mode 100644 Startserver.bat
#  create mode 100644 critools/__init__.py
#  create mode 100644 critools/__pycache__/__init__.cpython-37.pyc
#  create mode 100644 critools/__pycache__/admin.cpython-37.pyc
#  create mode 100644 critools/__pycache__/andon.cpython-37.pyc
#  create mode 100644 critools/__pycache__/apps.cpython-37.pyc
#  create mode 100644 critools/__pycache__/chart.cpython-37.pyc
#  create mode 100644 critools/__pycache__/data.cpython-37.pyc
#  create mode 100644 critools/__pycache__/models.cpython-37.pyc
#  create mode 100644 critools/__pycache__/urls.cpython-37.pyc
#  create mode 100644 critools/__pycache__/views.cpython-37.pyc
#  create mode 100644 critools/admin.py
#  create mode 100644 critools/andon.py
# ...

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ArjunAriyil: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@github.com/ArjunAriyil/djangoweb.git

# %%
# !git push -u origin master
# Out:
# Counting objects: 700, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (688/688), done.
# Writing objects: 100% (700/700), 7.80 MiB | 4.10 MiB/s, done.
# Total 700 (delta 221), reused 0 (delta 0)
# remote: Resolving deltas: 100% (221/221), done.
# To https://github.com/ArjunAriyil/djangoweb.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
